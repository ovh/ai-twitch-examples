# %% [markdown]
# <img src="attachment:3ad1595f-5096-4a7d-9b87-1d5a760aed16.png" width=200 align=right>

# %% [markdown]
# # Welcome in your AI Notebook 👋
#
# ➡ *Do you want to test an Object Detection algorithm?*
#
# <img src="attachment:22d429a9-ec2c-472c-ae17-c86564fa3456.png" width=800>

# %%
# clone yolov5 repository
# !git clone https://github.com/ultralytics/yolov5 /workspace/yolov5
# Out:
# Cloning into '/workspace/yolov5'...
# remote: Enumerating objects: 12164, done.
# remote: Total 12164 (delta 0), reused 0 (delta 0), pack-reused 12164
# Receiving objects: 100% (12164/12164), 11.95 MiB | 24.77 MiB/s, done.
# Resolving deltas: 100% (8425/8425), done.

# %%
# go to the yolov5 directory
# %cd /workspace/yolov5
# Out:
# /workspace/yolov5

# %%
# install dependencies
# !pip install -r requirements.txt

# %%
# import librairies
import glob
from IPython.display import Image, display

# %%
# detect objects on your own images 
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /workspace/images
# Out:
# detect: weights=['yolov5s.pt'], source=/workspace/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-242-ga80dd66 Python-3.9.5 torch-1.11.0+cu102 CUDA:0 (Tesla V100S-PCIE-32GB, 32510MiB)
#
# ...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:01<00:00, 12.1MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/3 /workspace/images/chien-960x640.jpg: 448x640 1 dog, Done. (0.008s)
# image 2/3 /workspace/images/policeman_horse.jpg: 480x640 9 persons, 7 cars, 1 traffic light, 2 horses, Done. (0.007s)
# ...

# %%
# display the resulting images
for imageName in glob.glob('/workspace/yolov5/runs/detect/exp/*.jpg'):
    display(Image(filename=imageName))
    print("\n")
